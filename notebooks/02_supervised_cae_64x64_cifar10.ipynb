# %% [markdown]
# # Supervised Autoencoder on CIFAR-10 — Notebook
#
# **Goal:** Train a supervised autoencoder (reconstruction + classification) on CIFAR-10

# %% [markdown]
# ## Environment & Reproducibility

# %%
import os
import math
import random
from pathlib import Path
import numpy as np
import torch
import torchvision

# %% [markdown]
# ## Config

# %%
from pprint import pprint

CONFIG = {
    # Data settings
    'seed'             : 42,
    'data_root'        : '../data',      # Path to dataset
    'num_classes'      : 10,             # CIFAR-10 → 10 classes
    'batch_size'       : 128,            # Samples per training batch
    'augment'          : True,           # Enable basic data augmentation (flips, crops, etc.)
    'num_workers'      : 4,              # Number of DataLoader workers
    'img_size'         : 64,             # Image resize dimension (height = width = 64)
    'split_train'      : 0.8,            # Train/validation split ratio (0.8 → 80% train, 20% val)

    # Model settings
    'latent_dim'       : 64,             # Latent vector dimension (e.g., 32, 64, 128)
    'loss_type'        : 'mse',          # Reconstruction loss: 'mse' (recommended) or 'bce'
    'lambda_recon'     : 50,             # Weight for reconstruction term (typical range: 0.1–50)
    'latent_noise_std' : 0.03,           # Std. dev. of Gaussian noise in latent space (train-time only)
                                         #   0.0  → deterministic encoder
                                         #   0.02–0.05 → mild smoothing (usually best)
                                         #   ≥0.1 → stronger noise, may reduce reconstruction accuracy
    'classifier_dropout': 0.25,          # Dropout rate for classifier head

    # Optimizer settings
    'lr'               : 3e-4,           # Learning rate (typical range: 1e-5 – 1e-3)
    'weight_decay'     : 5e-4,           # L2 regularization (weight decay)

    # Training settings
    'epochs'           : 40,             # Number of training epochs
}

pprint(CONFIG)
# Out:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 50,
#  'latent_dim': 64,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0003,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}

# %%
def set_seed(seed: int) -> None:
    """
    Set seeds for python, numpy, and torch (CPU and CUDA)
    to get reproducible behavior.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(CONFIG['seed'])

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# Device: cuda

# %% [markdown]
# ## Data Pipeline (CIFAR-10)

# %%
import torchvision.transforms as T
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, Subset, random_split  # random_split unused but kept

def get_transforms(augment: bool = True, resize_to: int = 64) -> tuple[T.Compose, T.Compose]:
    resize: T.Resize = T.Resize((resize_to, resize_to))
    
    train_tfms: T.Compose = T.Compose([
        resize,
        T.RandomCrop(resize_to, padding=4),
        T.RandomHorizontalFlip(),       
        T.ColorJitter(0.2, 0.2, 0.2, 0.1),
        T.ToTensor(), 
    ])
    
    test_val_tfms: T.Compose = T.Compose([
        resize,
        T.ToTensor(),
    ])
    
    if augment is True:
        return train_tfms, test_val_tfms
    else:
        train_tfms = test_val_tfms
        return train_tfms, test_val_tfms
        

def get_dataloaders(cfg: dict) -> tuple[DataLoader, DataLoader, DataLoader]:

    train_tfms, test_tfms = get_transforms(
        cfg['augment'],
        cfg['img_size'],
    )
    
    # Datasets
    test_set: CIFAR10 = CIFAR10(
        root=cfg['data_root'],
        train=False,
        transform=test_tfms,
        download=True
    )
    
    augment_train_set: CIFAR10 = CIFAR10(
        root=cfg['data_root'],
        train=True,
        transform=train_tfms,
        download=True
    )

    no_augment_train_set: CIFAR10 = CIFAR10(
        root=cfg['data_root'],
        train=True,
        transform=test_tfms,
        download=True
    )
    
    # Train/val split indices (reproducible with given seed)
    train_size: int = int(cfg['split_train'] * len(augment_train_set))
    valid_size: int = len(augment_train_set) - train_size
    
    dataset_indices: list[int] = list(range(len(augment_train_set)))

    rng = random.Random(CONFIG["seed"])  # local RNG, does NOT touch global random state
    shuffled_dataset_indices: list[int] = rng.sample(
        dataset_indices,
        k=len(dataset_indices)
    )
    
    train_idx: list[int] = shuffled_dataset_indices[:train_size]
    val_idx: list[int] = shuffled_dataset_indices[train_size:]
    
    train_set: Subset = Subset(
        dataset=augment_train_set,
        indices=train_idx
    )
    valid_set: Subset = Subset(
        dataset=no_augment_train_set,
        indices=val_idx
    )
    
    # DataLoaders
    train_loader: DataLoader = DataLoader(
        dataset=train_set,
        batch_size=cfg["batch_size"],
        shuffle=True,
        drop_last=True,
        pin_memory=True,
        persistent_workers=True,
        num_workers=cfg["num_workers"]
    )
    
    valid_loader: DataLoader = DataLoader(
        dataset=valid_set,
        batch_size=cfg["batch_size"],
        shuffle=False,
        drop_last=False,
        pin_memory=True,
        persistent_workers=True, 
        num_workers=cfg["num_workers"]
    )
    
    test_loader: DataLoader = DataLoader(
        dataset=test_set,
        batch_size=cfg["batch_size"],
        shuffle=False,
        drop_last=False,
        pin_memory=True,
        persistent_workers=True,
        num_workers=cfg["num_workers"]
    )
    
    # Debug prints
    print(f"All samples: {len(train_set)+len(valid_set)+len(test_set)}")
    print(f"Train samples: {len(train_set)}")
    print(f"Validation samples: {len(valid_set)}")
    print(f"Test samples: {len(test_set)}")

    image, label = augment_train_set[0]
    print(f"Single image shape: {image.shape}")
    
    return train_loader, valid_loader, test_loader

# Get the dataloader
train_loader, valid_loader, test_loader = get_dataloaders(CONFIG)

images, labels = next(iter(train_loader))

print(
    f"\n[INFO] Dataset summary:\n"
    f"       Images shape : {images.shape}\n"
    f"       Labels shape : {labels.shape}\n"
    f"       Pixel range  : [{images.min().item()}, {images.max().item()}]"
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# All samples: 60000
# Train samples: 40000
# Validation samples: 10000
# Test samples: 10000
# Single image shape: torch.Size([3, 64, 64])
#
# [INFO] Dataset summary:
#        Images shape : torch.Size([128, 3, 64, 64])
#        Labels shape : torch.Size([128])
#        Pixel range  : [0.0, 1.0]

# %%
# Exploration of train_loader
print("Step 1: train_loader type:", type(train_loader))
print("        Attributes:", [a for a in dir(train_loader) if not a.startswith('_')])

print("\nStep 2: train_loader.dataset type:", type(train_loader.dataset))
print("        Attributes:", [a for a in dir(train_loader.dataset) if not a.startswith('_')])

print("\nStep 3: train_loader.dataset.dataset type:", type(train_loader.dataset.dataset))
print("        Attributes:", [a for a in dir(train_loader.dataset.dataset) if not a.startswith('_')])

print("\nCIFAR10 classes:")
cifar10_classes = train_loader.dataset.dataset.classes
print(cifar10_classes)
# Out:
# Step 1: train_loader type: <class 'torch.utils.data.dataloader.DataLoader'>
#         Attributes: ['batch_sampler', 'batch_size', 'check_worker_number_rationality', 'collate_fn', 'dataset', 'drop_last', 'generator', 'multiprocessing_context', 'num_workers', 'persistent_workers', 'pin_memory', 'pin_memory_device', 'prefetch_factor', 'sampler', 'timeout', 'worker_init_fn']
#
# Step 2: train_loader.dataset type: <class 'torch.utils.data.dataset.Subset'>
#         Attributes: ['dataset', 'indices']
#
# Step 3: train_loader.dataset.dataset type: <class 'torchvision.datasets.cifar.CIFAR10'>
#         Attributes: ['base_folder', 'class_to_idx', 'classes', 'data', 'download', 'extra_repr', 'filename', 'meta', 'root', 'target_transform', 'targets', 'test_list', 'tgz_md5', 'train', 'train_list', 'transform', 'transforms', 'url']
#
# CIFAR10 classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## View a batch of images

# %%
import matplotlib.pyplot as plt

# Helper function to display an image grid
def show_image(image_tensor: torch.Tensor) -> None:
    """Convert a PyTorch tensor into a viewable image grid and show it."""

    # Step 1: Convert from a PyTorch tensor to a NumPy array (for matplotlib)
    # .detach() removes gradient tracking; .cpu() ensures data is on the CPU.
    image_grid_C_H_W: np.ndarray = image_tensor.detach().cpu().numpy()
    
    print("Shape before transpose:", image_grid_C_H_W.shape)  
    # (C, H, W) → C = number of color channels (3 for RGB), H = height, W = width

    # Step 2: Rearrange dimensions from (C, H, W) to (H, W, C)
    # because Matplotlib expects the color channel as the last dimension.
    image_grid_H_W_C: np.ndarray = np.transpose(image_grid_C_H_W, (1, 2, 0))
    print("Shape after transpose:", image_grid_H_W_C.shape)   # (H, W, C)

    # Step 3: Display the image
    plt.figure(figsize=(12, 12))
    plt.imshow(image_grid_H_W_C)
    plt.axis("off")  # hide axis numbers
    plt.show()
    
# Get a batch of training images
data_iter: iter = iter(train_loader)  # Create an iterator for the DataLoader
images: torch.Tensor
labels: torch.Tensor
images, labels = next(data_iter)   # Get one batch (images + labels)

# Make a grid from the batch
image_grid: torch.Tensor = torchvision.utils.make_grid(images, nrow=8)  # 8 images per row

# Show the grid
show_image(image_grid)
# Out:
# Shape before transpose: (3, 1058, 530)
# Shape after transpose: (1058, 530, 3)

# %% [markdown]
# ## Model — Encoder, Decoder, Classifier Head, SupervisedAE

# %%
import torch.nn as nn
from torch.nn.utils import clip_grad_norm_
from torchmetrics.classification import MulticlassAccuracy
from torchmetrics import MeanSquaredError

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dim: int = 64, latent_noise_std: float = 0.0) -> None:
        """
        Convolutional encoder: compresses an image (B, 3, 64, 64) into a latent vector (B, latent_dim).
        """
        super().__init__()
        self.latent_noise_std = latent_noise_std

        # Input: (B, 3, 64, 64)
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=3, 
                out_channels=32, 
                kernel_size=4, 
                stride=2, 
                padding=1
            ),  # -> (B, 32, 32, 32)
            nn.BatchNorm2d(num_features=32),
            nn.ReLU(inplace=True),
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=32, 
                out_channels=64, 
                kernel_size=4, 
                stride=2, 
                padding=1
            ),  # -> (B, 64, 16, 16)
            nn.BatchNorm2d(num_features=64),
            nn.ReLU(inplace=True),
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=64, 
                out_channels=128, 
                kernel_size=4, 
                stride=2, 
                padding=1
            ),  # -> (B, 128, 8, 8)
            nn.BatchNorm2d(num_features=128),
            nn.ReLU(inplace=True),
        )

        # Extra layer for 64x64 inputs (down to 4x4)
        self.conv4 = nn.Sequential(
            nn.Conv2d(
                in_channels=128, 
                out_channels=128, 
                kernel_size=4, 
                stride=2, 
                padding=1
            ),  # -> (B, 128, 4, 4)
            nn.BatchNorm2d(num_features=128),
            nn.ReLU(inplace=True),
        )

        # Flattened feature size after conv4: 128 × 4 × 4 = 2048
        self.flat_dim: int = 128 * 4 * 4

        # Fully connected (linear) layer: maps 2048 features → latent_dim
        # Performs: z = x @ W^T + b
        self.features_to_latent = nn.Linear(
            in_features=self.flat_dim,
            out_features=latent_dim,
            bias=True
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Encode a batch of images into latent features.
        """
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)

        # Flatten convolutional features: (B, 128, 4, 4) → (B, 2048)
        feat_flat = x.flatten(start_dim=1)

        # Linear projection: (B, 2048) → (B, latent_dim)
        z = self.features_to_latent(feat_flat)

        # Add Gaussian noise during training
        if self.training and self.latent_noise_std > 0.0:
            z = z + torch.randn_like(z) * self.latent_noise_std

        return z

# %%
# ------------------------------------------------------------
# Test the Encoder class with a random input
# ------------------------------------------------------------

# Create a batch of 8 random RGB images (like CIFAR-10 size: 3×64×64)
random_images = torch.rand(8, 3, 64, 64)

# Initialize the encoder
encoder = Encoder(latent_dim=64)

# Pass the images through the encoder to get latent vectors
latent_vectors = encoder(random_images)

# Print the shape of the output
print("Input batch shape:          ", random_images.shape)
print("Output latent vector shape: ", latent_vectors.shape)
print("Expected shape: (8, 64)  →  8 samples, each compressed into 64 features")
# Out:
# Input batch shape:           torch.Size([8, 3, 64, 64])
# Output latent vector shape:  torch.Size([8, 64])
# Expected shape: (8, 64)  →  8 samples, each compressed into 64 features

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim: int = 64) -> None:
        """
        Decoder: reconstructs an image (B, 3, 64, 64) from a latent vector (B, latent_dim).
        """
        super().__init__()

        # Flattened feature map size from the encoder: (128 × 4 × 4) = 2048
        self.flat_dim = 128 * 4 * 4

        # Fully connected (linear) layer: latent vector → flattened feature map
        # Performs: x = z @ W^T + b
        self.latent_to_features = nn.Linear(
            in_features=latent_dim,
            out_features=self.flat_dim,
            bias=True
        )

        self.decoder_cnn = nn.Sequential(

            # 4x4 → 8x8
            nn.ConvTranspose2d(
                in_channels=128,
                out_channels=64,
                kernel_size=4,
                stride=2,
                padding=1,
                bias=False
            ),
            nn.BatchNorm2d(num_features=64),
            nn.GELU(),

            # 8x8 → 16x16
            nn.ConvTranspose2d(
                in_channels=64,
                out_channels=32,
                kernel_size=4,
                stride=2,
                padding=1,
                bias=False
            ),
            nn.BatchNorm2d(num_features=32),
            nn.GELU(),

            # 16x16 → 32x32
            nn.ConvTranspose2d(
                in_channels=32,
                out_channels=16,
                kernel_size=4,
                stride=2,
                padding=1,
                bias=False
            ),
            nn.BatchNorm2d(num_features=16),
            nn.GELU(),

            # 32x32 → 64x64 (final RGB image)
            nn.ConvTranspose2d(
                in_channels=16,
                out_channels=3,
                kernel_size=4,
                stride=2,
                padding=1,
                bias=True
            ),

            # Output pixel values normalized to [0, 1]
            nn.Sigmoid(),
        )

    def forward(self, z: torch.Tensor) -> torch.Tensor:
        """
        Decode a latent vector into a reconstructed image.

        """
        # Linear projection: (B, latent_dim) → (B, 2048)
        x = self.latent_to_features(z)

        # Reshape flattened features into feature map (B, 128, 4, 4)
        x = x.view(z.size(0), 128, 4, 4)

        # Upsample step-by-step to full image size (B, 3, 64, 64)
        x_hat = self.decoder_cnn(x)

        return x_hat

# %%
# ------------------------------------------------------------
# Test the Decoder class with a random latent input
# ------------------------------------------------------------

# Create a batch of 8 random latent vectors (like output from the Encoder)
random_latents = torch.rand(8, 64)  # (B, latent_dim)

# Initialize the decoder
decoder = Decoder(latent_dim=64)

# Pass the latent vectors through the decoder to get reconstructed images
reconstructed_images = decoder(random_latents)

# Print the shape of the output
print("Input latent vector shape:    ", random_latents.shape)
print("Output reconstructed shape:   ", reconstructed_images.shape)
print("Expected shape: (8, 3, 64, 64)  →  8 images reconstructed from 64-D features")
# Out:
# Input latent vector shape:     torch.Size([8, 64])
# Output reconstructed shape:    torch.Size([8, 3, 64, 64])
# Expected shape: (8, 3, 64, 64)  →  8 images reconstructed from 64-D features

# %% [markdown]
# ### Classifier

# %%
class ClassifierHead(nn.Module):
    def __init__(self, latent_dim: int = 64, num_classes: int = 10, classifier_dropout: float = 0.0) -> None:
        """
        ClassifierHead: maps latent vectors (B, latent_dim) → class logits (B, num_classes).
        """
        super().__init__()

        # Hidden layer dimension — can be tuned for capacity (64, 128, 256)
        self.hidden_dim = 64

        # ------------------------------------------------------------
        # Simple MLP classifier: latent vector → hidden layer → logits
        # ------------------------------------------------------------
        self.mlp = nn.Sequential(

            # Fully connected layer: converts latent vector → hidden features
            nn.Linear(
                in_features=latent_dim,
                out_features=self.hidden_dim,
                bias=True
            ),

            # Normalize hidden features across the batch
            nn.BatchNorm1d(num_features=self.hidden_dim),

            # Apply non-linearity so the model can learn complex patterns
            nn.ReLU(inplace=True),

            # Randomly zero out some hidden units during training to prevent overfitting
            nn.Dropout(p=classifier_dropout),

            # Final layer: convert hidden features → class scores (logits)
            # (No softmax here — CrossEntropyLoss will handle it)
            nn.Linear(
                in_features=self.hidden_dim,
                out_features=num_classes,
                bias=True
            ),
        )

    def forward(self, z: torch.Tensor) -> torch.Tensor:
        """
        Forward pass: predict class logits from latent vectors.
        """
        logits = self.mlp(z)
        return logits

# %%
# ------------------------------------------------------------
# Test the ClassifierHead with random latent vectors
# ------------------------------------------------------------

# Create a batch of random latent vectors (like from the Encoder)
random_latents = torch.rand(8, 64)  # (B, latent_dim)

# Initialize the classifier head
classifier = ClassifierHead(latent_dim=64, num_classes=10, classifier_dropout=0.25)

# Pass the latent vectors through the classifier to get logits
logits = classifier(random_latents)

# Print the shapes for verification
print("Input latent shape: ", random_latents.shape)
print("Output logits shape:", logits.shape)
print("Expected shape: (8, 10)  →  8 samples, each with scores for 10 classes")
# Out:
# Input latent shape:  torch.Size([8, 64])
# Output logits shape: torch.Size([8, 10])
# Expected shape: (8, 10)  →  8 samples, each with scores for 10 classes

# %% [markdown]
# ### Supervised autoencoder

# %%
class SupervisedAE(nn.Module):
    def __init__(
        self,
        latent_dim: int = 64,
        num_classes: int = 10,
        lambda_recon: float = 0.25,
        latent_noise_std: float = 0.0,
        classifier_dropout: float = 0.0
    ) -> None:
        """
        Supervised Autoencoder:
        Combines an Encoder, Decoder, and ClassifierHead into one model.
        """
        super().__init__()

        # Store hyperparameters
        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.lambda_recon = lambda_recon
        self.latent_noise_std = latent_noise_std
        self.classifier_dropout = classifier_dropout

        # Step 1 — Define submodules

        # Encoder: image → latent vector
        self.encoder = Encoder(
            latent_dim=latent_dim,
            latent_noise_std=latent_noise_std
        )

        # Decoder: latent vector → reconstructed image
        self.decoder = Decoder(
            latent_dim=latent_dim
        )

        # Classifier: latent vector → class logits
        self.head = ClassifierHead(
            latent_dim=latent_dim,
            num_classes=num_classes,
            classifier_dropout=classifier_dropout
        )


    # Forward pass
    def forward(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """
        Run the full forward pass of the supervised autoencoder.

        """

        # Step 1 — Encode image to latent space
        z = self.encoder(x)

        # Step 2 — Decode latent back to image
        x_hat = self.decoder(z)

        # Step 3 — Predict class logits directly from latent representation
        logits = self.head(z)

        return z, x_hat, logits

# %%
# ------------------------------------------------------------
# Test the SupervisedAE (Encoder + Decoder + Classifier)
# ------------------------------------------------------------

# Create a batch of random RGB images (like CIFAR-10, 3×64×64)
random_images = torch.rand(8, 3, 64, 64)

# Initialize the Supervised Autoencoder
model = SupervisedAE(
    latent_dim=64,
    num_classes=10,
    lambda_recon=0.25,
    latent_noise_std=0.03,
    classifier_dropout=0.25
)

# Run a forward pass
z, x_hat, logits = model(random_images)

# Print output shapes for verification
print("Input batch shape:      ", random_images.shape)
print("Latent vector shape:    ", z.shape)
print("Reconstructed image:    ", x_hat.shape)
print("Class logits shape:     ", logits.shape)

print("\nExpected:")
print(" - Latent:        (8, 64)      → 8 samples, each 64-D encoded vector")
print(" - Reconstruction:(8, 3, 64, 64) → 8 decoded images")
print(" - Logits:        (8, 10)      → 8 samples, each with 10 class scores")
# Out:
# Input batch shape:       torch.Size([8, 3, 64, 64])
# Latent vector shape:     torch.Size([8, 64])
# Reconstructed image:     torch.Size([8, 3, 64, 64])
# Class logits shape:      torch.Size([8, 10])
#
# Expected:
#  - Latent:        (8, 64)      → 8 samples, each 64-D encoded vector
#  - Reconstruction:(8, 3, 64, 64) → 8 decoded images
#  - Logits:        (8, 10)      → 8 samples, each with 10 class scores

# %% [markdown]
# ## Loss functions

# %%
import torch.nn.functional as F

def reconstruction_loss(x_hat: torch.Tensor, x: torch.Tensor, loss_type: str = 'mse') -> torch.Tensor:
    """
    Compute reconstruction loss between model output and input.
    """
    if loss_type == 'mse':
        return F.mse_loss(x_hat, x)
    elif loss_type == 'bce':
        return F.binary_cross_entropy(x_hat, x)
    else:
        raise NotImplementedError(f"Loss type '{loss_type}' not implemented.")


def classification_loss(logits: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
    """
    Compute classification loss using cross-entropy.
    """
    return F.cross_entropy(logits, y)


def total_loss(
    logits: torch.Tensor,
    x_hat: torch.Tensor,
    y: torch.Tensor,
    x: torch.Tensor,
    lambda_recon: float = 0.25,
    loss_type: str = 'mse'
) -> torch.Tensor:
    """
    Combine classification and reconstruction losses.
    """
    recon_loss = reconstruction_loss(x_hat, x, loss_type)
    cls_loss = classification_loss(logits, y)
    total = cls_loss + lambda_recon * recon_loss
    return total

# %% [markdown]
# # Training Loop
#
# https://github.com/ageron/handson-mlp/blob/main/18_autoencoders_gans_and_diffusion_models.ipynb

# %%
from torch.nn.utils import clip_grad_norm_
from torchmetrics.classification import MulticlassAccuracy
from torchmetrics.regression import MeanSquaredError


@torch.no_grad()
def evaluate(model: torch.nn.Module, loader: torch.utils.data.DataLoader, device: str, loss_type: str) -> dict[str, float]:
    """
    Evaluate model performance on a dataset (no gradient computation).
    Returns averaged loss, accuracy, and RMSE.
    """
    model.eval()
    acc = MulticlassAccuracy(num_classes=model.num_classes).to(device)
    rmse = MeanSquaredError(squared=False).to(device)
    tot_loss: float = 0.0

    for X, y in loader:
        X, y = X.to(device), y.to(device)
        _, x_hat, logits = model(X)
        loss = total_loss(logits, x_hat, y, X, model.lambda_recon, loss_type)
        tot_loss += loss.item()
        acc.update(logits, y)  # argmax handled internally
        rmse.update(x_hat, X)

    n: int = len(loader)
    return {
        "loss": tot_loss / n,
        "acc": acc.compute().item(),
        "rmse": rmse.compute().item(),
    }


def train(
    model: torch.nn.Module,
    optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader,
    valid_loader: torch.utils.data.DataLoader,
    n_epochs: int = 10,
    device: str | None = None,
    max_grad_norm: float = 1.0,
    scheduler_patience: int = 2,
    scheduler_factor: float = 0.5,
    loss_type: str = "mse"
) -> dict[str, list[float]]:
    """
    Train the supervised autoencoder.
    Tracks and returns loss, accuracy, and RMSE for train and validation.
    """
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    acc_tm = MulticlassAccuracy(num_classes=model.num_classes).to(device)
    rmse_tm = MeanSquaredError(squared=False).to(device)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=scheduler_patience, factor=scheduler_factor
    )

    history: dict[str, list[float]] = {
        "train_loss": [], "train_acc": [], "train_rmse": [],
        "val_loss": [], "val_acc": [], "val_rmse": []
    }

    for epoch in range(1, n_epochs + 1):
        model.train()
        acc_tm.reset()
        rmse_tm.reset()
        running: float = 0.0

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            z, x_hat, logits = model(X)

            # L1 regularization term (penalize large latent activations)
            l1_loss: torch.Tensor = 5e-2 * z.abs().mean()

            # Compute total supervised autoencoder loss
            loss: torch.Tensor = total_loss(logits, x_hat, y, X, model.lambda_recon, loss_type)

            # Add regularization
            loss = loss + l1_loss

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)
            optimizer.step()

            running += loss.item()
            acc_tm.update(logits, y)
            rmse_tm.update(x_hat, X)

        # ---- Training metrics
        train_loss: float = running / len(train_loader)
        train_acc: float = acc_tm.compute().item()
        train_rmse: float = rmse_tm.compute().item()

        # ---- Validation metrics
        val_metrics: dict[str, float] = evaluate(model, valid_loader, device, loss_type)
        scheduler.step(val_metrics["acc"])  # reduce LR on plateau of val accuracy

        # ---- Log metrics
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_rmse"].append(train_rmse)
        history["val_loss"].append(val_metrics["loss"])
        history["val_acc"].append(val_metrics["acc"])
        history["val_rmse"].append(val_metrics["rmse"])

        print(
            f"Epoch {epoch:02d}/{n_epochs} | "
            f"train: loss {train_loss:.4f}, acc {train_acc:.3f}, rmse {train_rmse:.4f} | "
            f"val: loss {val_metrics['loss']:.4f}, acc {val_metrics['acc']:.3f}, rmse {val_metrics['rmse']:.4f}"
        )

    return history

# %% [markdown]
# ## Hyperparameters explorations

# %%
import random
from pprint import pprint

latent_dim_values   = [32, 64, 128]
lambda_recon_values = [0, 1, 10, 50]
lr_values           = [1e-4, 3e-4, 1e-3]

all_configs = []

# Build full grid of hyperparameter combinations
for ld in latent_dim_values:
    for lam in lambda_recon_values:
        for lr in lr_values:
            cfg = CONFIG.copy()
            cfg["latent_dim"]   = ld
            cfg["lambda_recon"] = lam
            cfg["lr"]           = lr
            all_configs.append(cfg)

# Randomly select N configurations from the grid
N = 5
random.shuffle(all_configs)
sampled_configs = all_configs[:N]   # only the chosen configs


# Add the original CONFIG as experiment 0
CONFIGS = []

# 0. Original config
CONFIGS.append(CONFIG.copy())

# 1..N. Random configs
CONFIGS.extend(sampled_configs)

# Print resulting experiment list
print("\nGenerated experiment configs:")
for i, c in enumerate(CONFIGS):
    print(f"\nExperiment {i}:")
    pprint(c)
# Out:
# Generated experiment configs:
#
# Experiment 0:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 50,
#  'latent_dim': 64,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0003,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# Experiment 1:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 50,
#  'latent_dim': 32,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# Experiment 2:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 0,
#  'latent_dim': 64,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# Experiment 3:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 1,
#  'latent_dim': 32,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# Experiment 4:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 1,
#  'latent_dim': 128,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# Experiment 5:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 10,
#  'latent_dim': 128,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}

# %% [markdown]
# ## Training model with (best) hyperparameters

# %%
experiments: list[dict] = []  # will store dicts with config, model, history

for i, cfg in enumerate(CONFIGS):
    print(f"\n========== EXPERIMENT {i} ==========")
    print("Using config:")
    pprint(cfg)

    # Create the model
    ae_model: SupervisedAE = SupervisedAE(
        latent_dim=cfg["latent_dim"],
        num_classes=cfg["num_classes"],
        lambda_recon=cfg["lambda_recon"],
        latent_noise_std=cfg["latent_noise_std"],
        classifier_dropout=cfg["classifier_dropout"],
    )

    # Print model configuration / hyperparameters
    print("\n[MODEL SETUP]")
    print("-------------------------------------------")
    print(f"Latent dimension         : {ae_model.latent_dim}")
    print(f"Number of classes        : {ae_model.num_classes}")
    print(f"lambda_recon (weight)    : {ae_model.lambda_recon}  <-- scales reconstruction loss")
    print(f"Latent noise std         : {ae_model.latent_noise_std}")
    print(f"Classifier dropout       : {ae_model.classifier_dropout}")
    print("-------------------------------------------\n")

    # Optimizer
    optimizer: torch.optim.Optimizer = torch.optim.NAdam(
        ae_model.parameters(),
        lr=cfg["lr"],
        weight_decay=cfg["weight_decay"],
    )

    # Train the model
    history: dict[str, list[float]] = train(
        model=ae_model,
        optimizer=optimizer,
        train_loader=train_loader,
        valid_loader=valid_loader,
        n_epochs=cfg["epochs"],
        loss_type=cfg["loss_type"],
    )

    # Store everything for later analysis
    experiments.append(
        {
            "config": cfg,
            "model": ae_model,
            "history": history,
        }
    )
# Out:
# ========== EXPERIMENT 0 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 50,
#  'latent_dim': 64,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0003,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 64
# Number of classes        : 10
# lambda_recon (weight)    : 50  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 3.2445, acc 0.399, rmse 0.1730 | val: loss 2.1445, acc 0.502, rmse 0.1211
# Epoch 02/40 | train: loss 2.0973, acc 0.511, rmse 0.1162 | val: loss 1.7389, acc 0.586, rmse 0.1059
# Epoch 03/40 | train: loss 1.8293, acc 0.568, rmse 0.1069 | val: loss 1.6501, acc 0.589, rmse 0.0988
# Epoch 04/40 | train: loss 1.6608, acc 0.607, rmse 0.1010 | val: loss 1.5232, acc 0.637, rmse 0.0989
# Epoch 05/40 | train: loss 1.5456, acc 0.638, rmse 0.0976 | val: loss 1.3465, acc 0.683, rmse 0.0948
# Epoch 06/40 | train: loss 1.4492, acc 0.667, rmse 0.0954 | val: loss 1.2585, acc 0.712, rmse 0.0930
# Epoch 07/40 | train: loss 1.3756, acc 0.685, rmse 0.0936 | val: loss 1.2330, acc 0.714, rmse 0.0912
# Epoch 08/40 | train: loss 1.3195, acc 0.701, rmse 0.0924 | val: loss 1.2352, acc 0.717, rmse 0.0924
# Epoch 09/40 | train: loss 1.2733, acc 0.714, rmse 0.0912 | val: loss 1.1676, acc 0.732, rmse 0.0907
# Epoch 10/40 | train: loss 1.2326, acc 0.727, rmse 0.0907 | val: loss 1.1121, acc 0.759, rmse 0.0909
# Epoch 11/40 | train: loss 1.1962, acc 0.738, rmse 0.0900 | val: loss 1.0982, acc 0.761, rmse 0.0903
# Epoch 12/40 | train: loss 1.1744, acc 0.744, rmse 0.0899 | val: loss 1.0922, acc 0.760, rmse 0.0888
# Epoch 13/40 | train: loss 1.1535, acc 0.752, rmse 0.0897 | val: loss 1.0707, acc 0.774, rmse 0.0906
# Epoch 14/40 | train: loss 1.1263, acc 0.760, rmse 0.0891 | val: loss 1.0617, acc 0.778, rmse 0.0908
# Epoch 15/40 | train: loss 1.1042, acc 0.767, rmse 0.0887 | val: loss 1.0754, acc 0.764, rmse 0.0889
# Epoch 16/40 | train: loss 1.0844, acc 0.773, rmse 0.0887 | val: loss 1.0363, acc 0.777, rmse 0.0890
# Epoch 17/40 | train: loss 1.0696, acc 0.775, rmse 0.0884 | val: loss 0.9930, acc 0.785, rmse 0.0865
# Epoch 18/40 | train: loss 1.0528, acc 0.781, rmse 0.0882 | val: loss 1.0233, acc 0.779, rmse 0.0876
# Epoch 19/40 | train: loss 1.0454, acc 0.784, rmse 0.0883 | val: loss 0.9874, acc 0.787, rmse 0.0867
# Epoch 20/40 | train: loss 1.0280, acc 0.790, rmse 0.0878 | val: loss 1.0413, acc 0.775, rmse 0.0892
# Epoch 21/40 | train: loss 1.0200, acc 0.792, rmse 0.0879 | val: loss 1.0199, acc 0.782, rmse 0.0875
# Epoch 22/40 | train: loss 1.0097, acc 0.795, rmse 0.0879 | val: loss 0.9577, acc 0.801, rmse 0.0871
# Epoch 23/40 | train: loss 0.9901, acc 0.801, rmse 0.0875 | val: loss 0.9597, acc 0.796, rmse 0.0865
# Epoch 24/40 | train: loss 0.9831, acc 0.802, rmse 0.0873 | val: loss 0.9510, acc 0.800, rmse 0.0862
# Epoch 25/40 | train: loss 0.9782, acc 0.806, rmse 0.0874 | val: loss 0.9655, acc 0.805, rmse 0.0899
# Epoch 26/40 | train: loss 0.9703, acc 0.807, rmse 0.0873 | val: loss 1.0076, acc 0.797, rmse 0.0907
# Epoch 27/40 | train: loss 0.9580, acc 0.812, rmse 0.0872 | val: loss 0.9427, acc 0.809, rmse 0.0889
# Epoch 28/40 | train: loss 0.9535, acc 0.811, rmse 0.0870 | val: loss 0.9297, acc 0.811, rmse 0.0882
# Epoch 29/40 | train: loss 0.9460, acc 0.815, rmse 0.0871 | val: loss 0.8938, acc 0.821, rmse 0.0864
# Epoch 30/40 | train: loss 0.9370, acc 0.817, rmse 0.0871 | val: loss 0.9622, acc 0.803, rmse 0.0884
# Epoch 31/40 | train: loss 0.9354, acc 0.818, rmse 0.0869 | val: loss 0.9202, acc 0.808, rmse 0.0860
# Epoch 32/40 | train: loss 0.9230, acc 0.823, rmse 0.0870 | val: loss 0.9170, acc 0.811, rmse 0.0853
# Epoch 33/40 | train: loss 0.8569, acc 0.844, rmse 0.0856 | val: loss 0.8428, acc 0.832, rmse 0.0841
# Epoch 34/40 | train: loss 0.8353, acc 0.850, rmse 0.0853 | val: loss 0.8481, acc 0.832, rmse 0.0851
# Epoch 35/40 | train: loss 0.8259, acc 0.854, rmse 0.0853 | val: loss 0.8313, acc 0.840, rmse 0.0849
# Epoch 36/40 | train: loss 0.8124, acc 0.858, rmse 0.0851 | val: loss 0.8259, acc 0.839, rmse 0.0842
# Epoch 37/40 | train: loss 0.8130, acc 0.859, rmse 0.0855 | val: loss 0.8204, acc 0.840, rmse 0.0840
# Epoch 38/40 | train: loss 0.8054, acc 0.859, rmse 0.0853 | val: loss 0.8463, acc 0.829, rmse 0.0846
# Epoch 39/40 | train: loss 0.7622, acc 0.875, rmse 0.0846 | val: loss 0.7921, acc 0.848, rmse 0.0831
# Epoch 40/40 | train: loss 0.7461, acc 0.879, rmse 0.0844 | val: loss 0.7825, acc 0.848, rmse 0.0829
#
# ========== EXPERIMENT 1 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 50,
#  'latent_dim': 32,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 32
# Number of classes        : 10
# lambda_recon (weight)    : 50  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 4.4288, acc 0.314, rmse 0.2216 | val: loss 2.8963, acc 0.432, rmse 0.1558
# Epoch 02/40 | train: loss 2.9415, acc 0.411, rmse 0.1564 | val: loss 2.3783, acc 0.480, rmse 0.1314
# Epoch 03/40 | train: loss 2.5007, acc 0.455, rmse 0.1355 | val: loss 2.1313, acc 0.516, rmse 0.1221
# Epoch 04/40 | train: loss 2.3008, acc 0.487, rmse 0.1277 | val: loss 1.9938, acc 0.551, rmse 0.1185
# Epoch 05/40 | train: loss 2.1676, acc 0.515, rmse 0.1237 | val: loss 1.8930, acc 0.576, rmse 0.1165
# Epoch 06/40 | train: loss 2.0669, acc 0.541, rmse 0.1214 | val: loss 1.8283, acc 0.591, rmse 0.1154
# Epoch 07/40 | train: loss 1.9798, acc 0.565, rmse 0.1198 | val: loss 1.7725, acc 0.612, rmse 0.1153
# Epoch 08/40 | train: loss 1.9194, acc 0.584, rmse 0.1189 | val: loss 1.7045, acc 0.626, rmse 0.1143
# Epoch 09/40 | train: loss 1.8582, acc 0.602, rmse 0.1177 | val: loss 1.6653, acc 0.640, rmse 0.1142
# Epoch 10/40 | train: loss 1.8078, acc 0.617, rmse 0.1169 | val: loss 1.6100, acc 0.654, rmse 0.1131
# Epoch 11/40 | train: loss 1.7623, acc 0.631, rmse 0.1162 | val: loss 1.6209, acc 0.661, rmse 0.1143
# Epoch 12/40 | train: loss 1.7182, acc 0.644, rmse 0.1155 | val: loss 1.5502, acc 0.680, rmse 0.1127
# Epoch 13/40 | train: loss 1.6794, acc 0.655, rmse 0.1147 | val: loss 1.5060, acc 0.693, rmse 0.1126
# Epoch 14/40 | train: loss 1.6411, acc 0.665, rmse 0.1141 | val: loss 1.4955, acc 0.697, rmse 0.1121
# Epoch 15/40 | train: loss 1.6001, acc 0.675, rmse 0.1133 | val: loss 1.4490, acc 0.713, rmse 0.1123
# Epoch 16/40 | train: loss 1.5736, acc 0.685, rmse 0.1129 | val: loss 1.4389, acc 0.711, rmse 0.1112
# Epoch 17/40 | train: loss 1.5453, acc 0.689, rmse 0.1123 | val: loss 1.4117, acc 0.722, rmse 0.1110
# Epoch 18/40 | train: loss 1.5200, acc 0.696, rmse 0.1117 | val: loss 1.3872, acc 0.733, rmse 0.1110
# Epoch 19/40 | train: loss 1.4954, acc 0.705, rmse 0.1114 | val: loss 1.4130, acc 0.717, rmse 0.1106
# Epoch 20/40 | train: loss 1.4727, acc 0.711, rmse 0.1110 | val: loss 1.3838, acc 0.728, rmse 0.1107
# Epoch 21/40 | train: loss 1.4536, acc 0.719, rmse 0.1109 | val: loss 1.3469, acc 0.738, rmse 0.1099
# Epoch 22/40 | train: loss 1.4381, acc 0.722, rmse 0.1106 | val: loss 1.3391, acc 0.743, rmse 0.1097
# Epoch 23/40 | train: loss 1.4108, acc 0.732, rmse 0.1100 | val: loss 1.3178, acc 0.749, rmse 0.1097
# Epoch 24/40 | train: loss 1.3943, acc 0.736, rmse 0.1099 | val: loss 1.3098, acc 0.750, rmse 0.1094
# Epoch 25/40 | train: loss 1.3767, acc 0.741, rmse 0.1095 | val: loss 1.2994, acc 0.753, rmse 0.1094
# Epoch 26/40 | train: loss 1.3710, acc 0.742, rmse 0.1095 | val: loss 1.2996, acc 0.760, rmse 0.1097
# Epoch 27/40 | train: loss 1.3512, acc 0.749, rmse 0.1094 | val: loss 1.2840, acc 0.761, rmse 0.1092
# Epoch 28/40 | train: loss 1.3364, acc 0.754, rmse 0.1092 | val: loss 1.2704, acc 0.761, rmse 0.1089
# Epoch 29/40 | train: loss 1.3270, acc 0.757, rmse 0.1092 | val: loss 1.2654, acc 0.766, rmse 0.1089
# Epoch 30/40 | train: loss 1.3181, acc 0.757, rmse 0.1090 | val: loss 1.2534, acc 0.771, rmse 0.1095
# Epoch 31/40 | train: loss 1.3032, acc 0.764, rmse 0.1089 | val: loss 1.2994, acc 0.753, rmse 0.1093
# Epoch 32/40 | train: loss 1.2935, acc 0.768, rmse 0.1090 | val: loss 1.2484, acc 0.774, rmse 0.1095
# Epoch 33/40 | train: loss 1.2902, acc 0.770, rmse 0.1090 | val: loss 1.2987, acc 0.755, rmse 0.1087
# Epoch 34/40 | train: loss 1.2714, acc 0.777, rmse 0.1089 | val: loss 1.2829, acc 0.763, rmse 0.1100
# Epoch 35/40 | train: loss 1.2645, acc 0.782, rmse 0.1089 | val: loss 1.2132, acc 0.786, rmse 0.1089
# Epoch 36/40 | train: loss 1.2619, acc 0.780, rmse 0.1088 | val: loss 1.2265, acc 0.776, rmse 0.1090
# Epoch 37/40 | train: loss 1.2552, acc 0.782, rmse 0.1088 | val: loss 1.2329, acc 0.783, rmse 0.1090
# Epoch 38/40 | train: loss 1.2385, acc 0.786, rmse 0.1087 | val: loss 1.2199, acc 0.777, rmse 0.1085
# Epoch 39/40 | train: loss 1.2007, acc 0.802, rmse 0.1084 | val: loss 1.1732, acc 0.796, rmse 0.1079
# Epoch 40/40 | train: loss 1.1810, acc 0.808, rmse 0.1080 | val: loss 1.1600, acc 0.804, rmse 0.1081
#
# ========== EXPERIMENT 2 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 0,
#  'latent_dim': 64,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 64
# Number of classes        : 10
# lambda_recon (weight)    : 0  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 1.8373, acc 0.373, rmse 0.2874 | val: loss 1.4848, acc 0.506, rmse 0.2554
# Epoch 02/40 | train: loss 1.5249, acc 0.489, rmse 0.2802 | val: loss 1.3110, acc 0.567, rmse 0.2492
# Epoch 03/40 | train: loss 1.3737, acc 0.541, rmse 0.2730 | val: loss 1.1818, acc 0.599, rmse 0.2448
# Epoch 04/40 | train: loss 1.2630, acc 0.579, rmse 0.2710 | val: loss 1.0637, acc 0.635, rmse 0.2451
# Epoch 05/40 | train: loss 1.1762, acc 0.608, rmse 0.2719 | val: loss 1.0025, acc 0.656, rmse 0.2453
# Epoch 06/40 | train: loss 1.1059, acc 0.634, rmse 0.2724 | val: loss 0.9400, acc 0.677, rmse 0.2454
# Epoch 07/40 | train: loss 1.0488, acc 0.655, rmse 0.2721 | val: loss 0.9021, acc 0.695, rmse 0.2455
# Epoch 08/40 | train: loss 0.9974, acc 0.671, rmse 0.2725 | val: loss 0.8673, acc 0.707, rmse 0.2456
# Epoch 09/40 | train: loss 0.9459, acc 0.689, rmse 0.2723 | val: loss 0.8154, acc 0.729, rmse 0.2456
# Epoch 10/40 | train: loss 0.9136, acc 0.700, rmse 0.2724 | val: loss 0.8103, acc 0.720, rmse 0.2457
# Epoch 11/40 | train: loss 0.8768, acc 0.710, rmse 0.2726 | val: loss 0.7500, acc 0.742, rmse 0.2457
# Epoch 12/40 | train: loss 0.8491, acc 0.719, rmse 0.2725 | val: loss 0.7358, acc 0.751, rmse 0.2457
# Epoch 13/40 | train: loss 0.8248, acc 0.728, rmse 0.2724 | val: loss 0.7215, acc 0.755, rmse 0.2457
# Epoch 14/40 | train: loss 0.7970, acc 0.739, rmse 0.2726 | val: loss 0.7023, acc 0.762, rmse 0.2457
# Epoch 15/40 | train: loss 0.7799, acc 0.744, rmse 0.2728 | val: loss 0.6757, acc 0.773, rmse 0.2457
# Epoch 16/40 | train: loss 0.7593, acc 0.750, rmse 0.2723 | val: loss 0.6871, acc 0.766, rmse 0.2457
# Epoch 17/40 | train: loss 0.7367, acc 0.760, rmse 0.2724 | val: loss 0.6627, acc 0.772, rmse 0.2457
# Epoch 18/40 | train: loss 0.7258, acc 0.761, rmse 0.2725 | val: loss 0.6490, acc 0.777, rmse 0.2457
# Epoch 19/40 | train: loss 0.7113, acc 0.767, rmse 0.2725 | val: loss 0.6444, acc 0.779, rmse 0.2457
# Epoch 20/40 | train: loss 0.6895, acc 0.775, rmse 0.2727 | val: loss 0.6559, acc 0.775, rmse 0.2457
# Epoch 21/40 | train: loss 0.6714, acc 0.780, rmse 0.2727 | val: loss 0.6191, acc 0.787, rmse 0.2457
# Epoch 22/40 | train: loss 0.6638, acc 0.781, rmse 0.2727 | val: loss 0.6141, acc 0.788, rmse 0.2457
# Epoch 23/40 | train: loss 0.6495, acc 0.788, rmse 0.2726 | val: loss 0.5999, acc 0.795, rmse 0.2457
# Epoch 24/40 | train: loss 0.6405, acc 0.790, rmse 0.2726 | val: loss 0.6083, acc 0.788, rmse 0.2457
# Epoch 25/40 | train: loss 0.6293, acc 0.796, rmse 0.2724 | val: loss 0.5951, acc 0.799, rmse 0.2457
# Epoch 26/40 | train: loss 0.6212, acc 0.795, rmse 0.2724 | val: loss 0.5785, acc 0.801, rmse 0.2457
# Epoch 27/40 | train: loss 0.6059, acc 0.803, rmse 0.2726 | val: loss 0.5703, acc 0.805, rmse 0.2457
# Epoch 28/40 | train: loss 0.6018, acc 0.803, rmse 0.2725 | val: loss 0.5812, acc 0.799, rmse 0.2457
# Epoch 29/40 | train: loss 0.5883, acc 0.808, rmse 0.2725 | val: loss 0.5725, acc 0.805, rmse 0.2457
# Epoch 30/40 | train: loss 0.5836, acc 0.810, rmse 0.2729 | val: loss 0.5741, acc 0.800, rmse 0.2457
# Epoch 31/40 | train: loss 0.5731, acc 0.812, rmse 0.2727 | val: loss 0.5773, acc 0.799, rmse 0.2457
# Epoch 32/40 | train: loss 0.5643, acc 0.817, rmse 0.2724 | val: loss 0.5680, acc 0.806, rmse 0.2457
# Epoch 33/40 | train: loss 0.5555, acc 0.820, rmse 0.2720 | val: loss 0.5482, acc 0.810, rmse 0.2457
# Epoch 34/40 | train: loss 0.5528, acc 0.821, rmse 0.2726 | val: loss 0.5536, acc 0.811, rmse 0.2457
# Epoch 35/40 | train: loss 0.5500, acc 0.820, rmse 0.2724 | val: loss 0.5538, acc 0.806, rmse 0.2457
# Epoch 36/40 | train: loss 0.5365, acc 0.828, rmse 0.2722 | val: loss 0.5383, acc 0.816, rmse 0.2457
# Epoch 37/40 | train: loss 0.5302, acc 0.830, rmse 0.2725 | val: loss 0.5380, acc 0.817, rmse 0.2457
# Epoch 38/40 | train: loss 0.5289, acc 0.830, rmse 0.2726 | val: loss 0.5400, acc 0.816, rmse 0.2457
# Epoch 39/40 | train: loss 0.5146, acc 0.834, rmse 0.2724 | val: loss 0.5382, acc 0.815, rmse 0.2457
# Epoch 40/40 | train: loss 0.5100, acc 0.838, rmse 0.2724 | val: loss 0.5441, acc 0.811, rmse 0.2457
#
# ========== EXPERIMENT 3 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 1,
#  'latent_dim': 32,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 32
# Number of classes        : 10
# lambda_recon (weight)    : 1  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 1.6288, acc 0.444, rmse 0.2007 | val: loss 1.3550, acc 0.529, rmse 0.2121
# Epoch 02/40 | train: loss 1.2353, acc 0.589, rmse 0.1819 | val: loss 1.0146, acc 0.650, rmse 0.1783
# Epoch 03/40 | train: loss 1.0654, acc 0.649, rmse 0.1801 | val: loss 1.0505, acc 0.641, rmse 0.1972
# Epoch 04/40 | train: loss 0.9812, acc 0.679, rmse 0.1794 | val: loss 0.9090, acc 0.696, rmse 0.1728
# Epoch 05/40 | train: loss 0.9058, acc 0.707, rmse 0.1787 | val: loss 0.8502, acc 0.717, rmse 0.1782
# Epoch 06/40 | train: loss 0.8593, acc 0.722, rmse 0.1760 | val: loss 0.8290, acc 0.718, rmse 0.1643
# Epoch 07/40 | train: loss 0.8147, acc 0.738, rmse 0.1736 | val: loss 0.7046, acc 0.757, rmse 0.1618
# Epoch 08/40 | train: loss 0.7789, acc 0.750, rmse 0.1686 | val: loss 0.7440, acc 0.757, rmse 0.1613
# Epoch 09/40 | train: loss 0.7457, acc 0.759, rmse 0.1724 | val: loss 0.7298, acc 0.753, rmse 0.1583
# Epoch 10/40 | train: loss 0.7275, acc 0.768, rmse 0.1686 | val: loss 0.7296, acc 0.758, rmse 0.1827
# Epoch 11/40 | train: loss 0.7055, acc 0.776, rmse 0.1715 | val: loss 0.7645, acc 0.745, rmse 0.1702
# Epoch 12/40 | train: loss 0.6935, acc 0.778, rmse 0.1695 | val: loss 0.6930, acc 0.765, rmse 0.1638
# Epoch 13/40 | train: loss 0.6835, acc 0.782, rmse 0.1699 | val: loss 0.8030, acc 0.782, rmse 0.4066
# Epoch 14/40 | train: loss 0.6714, acc 0.786, rmse 0.1740 | val: loss 0.6551, acc 0.778, rmse 0.1606
# Epoch 15/40 | train: loss 0.6621, acc 0.788, rmse 0.1703 | val: loss 0.6193, acc 0.793, rmse 0.1583
# Epoch 16/40 | train: loss 0.6568, acc 0.790, rmse 0.1733 | val: loss 0.6781, acc 0.778, rmse 0.1589
# Epoch 17/40 | train: loss 0.6516, acc 0.794, rmse 0.1700 | val: loss 0.6572, acc 0.784, rmse 0.1586
# Epoch 18/40 | train: loss 0.6481, acc 0.793, rmse 0.1700 | val: loss 0.6369, acc 0.790, rmse 0.1609
# Epoch 19/40 | train: loss 0.5685, acc 0.820, rmse 0.1667 | val: loss 0.5658, acc 0.814, rmse 0.1551
# Epoch 20/40 | train: loss 0.5366, acc 0.833, rmse 0.1659 | val: loss 0.5507, acc 0.822, rmse 0.1577
# Epoch 21/40 | train: loss 0.5314, acc 0.835, rmse 0.1660 | val: loss 0.5466, acc 0.821, rmse 0.1604
# Epoch 22/40 | train: loss 0.5196, acc 0.838, rmse 0.1655 | val: loss 0.5270, acc 0.828, rmse 0.1527
# Epoch 23/40 | train: loss 0.5168, acc 0.838, rmse 0.1657 | val: loss 0.5184, acc 0.831, rmse 0.1546
# Epoch 24/40 | train: loss 0.5100, acc 0.839, rmse 0.1659 | val: loss 0.5296, acc 0.825, rmse 0.1536
# Epoch 25/40 | train: loss 0.5049, acc 0.841, rmse 0.1657 | val: loss 0.5541, acc 0.818, rmse 0.1515
# Epoch 26/40 | train: loss 0.5049, acc 0.842, rmse 0.1661 | val: loss 0.5304, acc 0.828, rmse 0.1542
# Epoch 27/40 | train: loss 0.4508, acc 0.861, rmse 0.1638 | val: loss 0.4842, acc 0.841, rmse 0.1510
# Epoch 28/40 | train: loss 0.4291, acc 0.870, rmse 0.1634 | val: loss 0.4865, acc 0.840, rmse 0.1498
# Epoch 29/40 | train: loss 0.4255, acc 0.869, rmse 0.1629 | val: loss 0.4816, acc 0.843, rmse 0.1497
# Epoch 30/40 | train: loss 0.4214, acc 0.872, rmse 0.1628 | val: loss 0.4801, acc 0.844, rmse 0.1501
# Epoch 31/40 | train: loss 0.4113, acc 0.875, rmse 0.1626 | val: loss 0.4801, acc 0.845, rmse 0.1498
# Epoch 32/40 | train: loss 0.4102, acc 0.876, rmse 0.1630 | val: loss 0.4765, acc 0.847, rmse 0.1493
# Epoch 33/40 | train: loss 0.3976, acc 0.880, rmse 0.1623 | val: loss 0.4664, acc 0.848, rmse 0.1492
# Epoch 34/40 | train: loss 0.3976, acc 0.879, rmse 0.1626 | val: loss 0.4650, acc 0.847, rmse 0.1505
# Epoch 35/40 | train: loss 0.3956, acc 0.879, rmse 0.1636 | val: loss 0.4677, acc 0.849, rmse 0.1532
# Epoch 36/40 | train: loss 0.3961, acc 0.880, rmse 0.1631 | val: loss 0.5015, acc 0.838, rmse 0.1498
# Epoch 37/40 | train: loss 0.3891, acc 0.884, rmse 0.1638 | val: loss 0.4594, acc 0.853, rmse 0.1491
# Epoch 38/40 | train: loss 0.3933, acc 0.880, rmse 0.1638 | val: loss 0.4747, acc 0.848, rmse 0.1498
# Epoch 39/40 | train: loss 0.3872, acc 0.882, rmse 0.1634 | val: loss 0.4963, acc 0.840, rmse 0.1512
# Epoch 40/40 | train: loss 0.3910, acc 0.880, rmse 0.1640 | val: loss 0.5182, acc 0.833, rmse 0.1505
#
# ========== EXPERIMENT 4 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 1,
#  'latent_dim': 128,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.0001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 128
# Number of classes        : 10
# lambda_recon (weight)    : 1  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 1.8627, acc 0.378, rmse 0.2270 | val: loss 1.5054, acc 0.502, rmse 0.1690
# Epoch 02/40 | train: loss 1.5352, acc 0.498, rmse 0.1696 | val: loss 1.3298, acc 0.560, rmse 0.1535
# Epoch 03/40 | train: loss 1.3752, acc 0.551, rmse 0.1546 | val: loss 1.2075, acc 0.605, rmse 0.1451
# Epoch 04/40 | train: loss 1.2596, acc 0.590, rmse 0.1494 | val: loss 1.0913, acc 0.638, rmse 0.1401
# Epoch 05/40 | train: loss 1.1748, acc 0.617, rmse 0.1463 | val: loss 1.0103, acc 0.670, rmse 0.1414
# Epoch 06/40 | train: loss 1.1129, acc 0.641, rmse 0.1442 | val: loss 0.9615, acc 0.686, rmse 0.1379
# Epoch 07/40 | train: loss 1.0563, acc 0.658, rmse 0.1441 | val: loss 0.9025, acc 0.704, rmse 0.1408
# Epoch 08/40 | train: loss 1.0105, acc 0.675, rmse 0.1431 | val: loss 0.8707, acc 0.711, rmse 0.1364
# Epoch 09/40 | train: loss 0.9647, acc 0.689, rmse 0.1423 | val: loss 0.8551, acc 0.710, rmse 0.1354
# Epoch 10/40 | train: loss 0.9333, acc 0.699, rmse 0.1420 | val: loss 0.8230, acc 0.723, rmse 0.1350
# Epoch 11/40 | train: loss 0.9019, acc 0.708, rmse 0.1422 | val: loss 0.8033, acc 0.732, rmse 0.1351
# Epoch 12/40 | train: loss 0.8770, acc 0.716, rmse 0.1419 | val: loss 0.7584, acc 0.751, rmse 0.1359
# Epoch 13/40 | train: loss 0.8501, acc 0.726, rmse 0.1423 | val: loss 0.7514, acc 0.744, rmse 0.1354
# Epoch 14/40 | train: loss 0.8283, acc 0.734, rmse 0.1423 | val: loss 0.7465, acc 0.752, rmse 0.1349
# Epoch 15/40 | train: loss 0.8067, acc 0.739, rmse 0.1429 | val: loss 0.7245, acc 0.756, rmse 0.1333
# Epoch 16/40 | train: loss 0.7917, acc 0.744, rmse 0.1434 | val: loss 0.7358, acc 0.754, rmse 0.1341
# Epoch 17/40 | train: loss 0.7698, acc 0.753, rmse 0.1439 | val: loss 0.7000, acc 0.763, rmse 0.1327
# Epoch 18/40 | train: loss 0.7610, acc 0.757, rmse 0.1446 | val: loss 0.6737, acc 0.776, rmse 0.1329
# Epoch 19/40 | train: loss 0.7422, acc 0.765, rmse 0.1454 | val: loss 0.6633, acc 0.779, rmse 0.1348
# Epoch 20/40 | train: loss 0.7292, acc 0.767, rmse 0.1458 | val: loss 0.6527, acc 0.782, rmse 0.1350
# Epoch 21/40 | train: loss 0.7156, acc 0.772, rmse 0.1471 | val: loss 0.6798, acc 0.777, rmse 0.1381
# Epoch 22/40 | train: loss 0.7034, acc 0.775, rmse 0.1476 | val: loss 0.6481, acc 0.786, rmse 0.1357
# Epoch 23/40 | train: loss 0.6911, acc 0.780, rmse 0.1491 | val: loss 0.6436, acc 0.787, rmse 0.1384
# Epoch 24/40 | train: loss 0.6788, acc 0.785, rmse 0.1505 | val: loss 0.6387, acc 0.786, rmse 0.1369
# Epoch 25/40 | train: loss 0.6741, acc 0.786, rmse 0.1513 | val: loss 0.6642, acc 0.780, rmse 0.1420
# Epoch 26/40 | train: loss 0.6579, acc 0.793, rmse 0.1528 | val: loss 0.6180, acc 0.794, rmse 0.1415
# Epoch 27/40 | train: loss 0.6551, acc 0.793, rmse 0.1533 | val: loss 0.6142, acc 0.797, rmse 0.1404
# Epoch 28/40 | train: loss 0.6428, acc 0.799, rmse 0.1542 | val: loss 0.5992, acc 0.804, rmse 0.1415
# Epoch 29/40 | train: loss 0.6337, acc 0.803, rmse 0.1546 | val: loss 0.6175, acc 0.795, rmse 0.1439
# Epoch 30/40 | train: loss 0.6267, acc 0.804, rmse 0.1554 | val: loss 0.5915, acc 0.808, rmse 0.1408
# Epoch 31/40 | train: loss 0.6143, acc 0.808, rmse 0.1557 | val: loss 0.6254, acc 0.793, rmse 0.1433
# Epoch 32/40 | train: loss 0.6068, acc 0.811, rmse 0.1570 | val: loss 0.6071, acc 0.798, rmse 0.1439
# Epoch 33/40 | train: loss 0.6032, acc 0.813, rmse 0.1573 | val: loss 0.6014, acc 0.803, rmse 0.1442
# Epoch 34/40 | train: loss 0.5633, acc 0.827, rmse 0.1563 | val: loss 0.5655, acc 0.815, rmse 0.1420
# Epoch 35/40 | train: loss 0.5465, acc 0.835, rmse 0.1562 | val: loss 0.5641, acc 0.816, rmse 0.1430
# Epoch 36/40 | train: loss 0.5424, acc 0.835, rmse 0.1572 | val: loss 0.5533, acc 0.820, rmse 0.1431
# Epoch 37/40 | train: loss 0.5296, acc 0.841, rmse 0.1567 | val: loss 0.5472, acc 0.819, rmse 0.1414
# Epoch 38/40 | train: loss 0.5222, acc 0.842, rmse 0.1575 | val: loss 0.5456, acc 0.823, rmse 0.1440
# Epoch 39/40 | train: loss 0.5210, acc 0.843, rmse 0.1574 | val: loss 0.5476, acc 0.819, rmse 0.1440
# Epoch 40/40 | train: loss 0.5171, acc 0.845, rmse 0.1577 | val: loss 0.5435, acc 0.825, rmse 0.1453
#
# ========== EXPERIMENT 5 ==========
# Using config:
# {'augment': True,
#  'batch_size': 128,
#  'classifier_dropout': 0.25,
#  'data_root': '../data',
#  'epochs': 40,
#  'img_size': 64,
#  'lambda_recon': 10,
#  'latent_dim': 128,
#  'latent_noise_std': 0.03,
#  'loss_type': 'mse',
#  'lr': 0.001,
#  'num_classes': 10,
#  'num_workers': 4,
#  'seed': 42,
#  'split_train': 0.8,
#  'weight_decay': 0.0005}
#
# [MODEL SETUP]
# -------------------------------------------
# Latent dimension         : 128
# Number of classes        : 10
# lambda_recon (weight)    : 10  <-- scales reconstruction loss
# Latent noise std         : 0.03
# Classifier dropout       : 0.25
# -------------------------------------------
#
# Epoch 01/40 | train: loss 1.8283, acc 0.448, rmse 0.1590 | val: loss 1.3702, acc 0.574, rmse 0.1295
# Epoch 02/40 | train: loss 1.3769, acc 0.579, rmse 0.1225 | val: loss 1.2964, acc 0.627, rmse 0.1620
# Epoch 03/40 | train: loss 1.2073, acc 0.637, rmse 0.1170 | val: loss 1.1160, acc 0.685, rmse 0.1470
# Epoch 04/40 | train: loss 1.1066, acc 0.674, rmse 0.1152 | val: loss 0.9792, acc 0.706, rmse 0.1159
# Epoch 05/40 | train: loss 1.0351, acc 0.690, rmse 0.1098 | val: loss 0.9095, acc 0.732, rmse 0.1176
# Epoch 06/40 | train: loss 0.9920, acc 0.709, rmse 0.1138 | val: loss 0.9185, acc 0.712, rmse 0.1034
# Epoch 07/40 | train: loss 0.9502, acc 0.724, rmse 0.1131 | val: loss 0.8838, acc 0.735, rmse 0.1057
# Epoch 08/40 | train: loss 0.9066, acc 0.734, rmse 0.1069 | val: loss 0.8407, acc 0.750, rmse 0.1102
# Epoch 09/40 | train: loss 0.8795, acc 0.742, rmse 0.1066 | val: loss 0.8573, acc 0.749, rmse 0.1153
# Epoch 10/40 | train: loss 0.8496, acc 0.750, rmse 0.1055 | val: loss 0.9038, acc 0.724, rmse 0.1076
# Epoch 11/40 | train: loss 0.8466, acc 0.758, rmse 0.1126 | val: loss 0.7934, acc 0.770, rmse 0.1169
# Epoch 12/40 | train: loss 0.8185, acc 0.764, rmse 0.1054 | val: loss 0.7262, acc 0.780, rmse 0.1006
# Epoch 13/40 | train: loss 0.8017, acc 0.767, rmse 0.1047 | val: loss 0.7423, acc 0.773, rmse 0.0997
# Epoch 14/40 | train: loss 0.7934, acc 0.770, rmse 0.1040 | val: loss 0.7887, acc 0.763, rmse 0.1019
# Epoch 15/40 | train: loss 0.7802, acc 0.773, rmse 0.1034 | val: loss 0.7651, acc 0.764, rmse 0.0997
# Epoch 16/40 | train: loss 0.6827, acc 0.804, rmse 0.0973 | val: loss 0.6681, acc 0.799, rmse 0.0922
# Epoch 17/40 | train: loss 0.6525, acc 0.814, rmse 0.0965 | val: loss 0.6434, acc 0.808, rmse 0.0932
# Epoch 18/40 | train: loss 0.6426, acc 0.818, rmse 0.0963 | val: loss 0.6264, acc 0.815, rmse 0.0921
# Epoch 19/40 | train: loss 0.6356, acc 0.821, rmse 0.0963 | val: loss 0.5971, acc 0.820, rmse 0.0902
# Epoch 20/40 | train: loss 0.6201, acc 0.823, rmse 0.0959 | val: loss 0.6596, acc 0.803, rmse 0.0898
# Epoch 21/40 | train: loss 0.6149, acc 0.826, rmse 0.0960 | val: loss 0.5993, acc 0.820, rmse 0.0935
# Epoch 22/40 | train: loss 0.6093, acc 0.827, rmse 0.0956 | val: loss 0.5850, acc 0.826, rmse 0.0907
# Epoch 23/40 | train: loss 0.6101, acc 0.829, rmse 0.0953 | val: loss 0.6072, acc 0.817, rmse 0.0895
# Epoch 24/40 | train: loss 0.6056, acc 0.829, rmse 0.0956 | val: loss 0.6071, acc 0.819, rmse 0.0919
# Epoch 25/40 | train: loss 0.5964, acc 0.834, rmse 0.0950 | val: loss 0.5997, acc 0.823, rmse 0.0890
# Epoch 26/40 | train: loss 0.5415, acc 0.850, rmse 0.0922 | val: loss 0.5475, acc 0.838, rmse 0.0864
# Epoch 27/40 | train: loss 0.5120, acc 0.860, rmse 0.0914 | val: loss 0.5488, acc 0.839, rmse 0.0852
# Epoch 28/40 | train: loss 0.5031, acc 0.861, rmse 0.0912 | val: loss 0.5257, acc 0.844, rmse 0.0850
# Epoch 29/40 | train: loss 0.4965, acc 0.866, rmse 0.0908 | val: loss 0.5272, acc 0.845, rmse 0.0868
# Epoch 30/40 | train: loss 0.4922, acc 0.865, rmse 0.0906 | val: loss 0.5318, acc 0.844, rmse 0.0842
# Epoch 31/40 | train: loss 0.4889, acc 0.865, rmse 0.0908 | val: loss 0.5441, acc 0.839, rmse 0.0834
# Epoch 32/40 | train: loss 0.4808, acc 0.870, rmse 0.0909 | val: loss 0.5298, acc 0.843, rmse 0.0834
# Epoch 33/40 | train: loss 0.4432, acc 0.880, rmse 0.0893 | val: loss 0.4976, acc 0.853, rmse 0.0816
# Epoch 34/40 | train: loss 0.4320, acc 0.885, rmse 0.0886 | val: loss 0.4938, acc 0.852, rmse 0.0813
# Epoch 35/40 | train: loss 0.4277, acc 0.887, rmse 0.0884 | val: loss 0.4910, acc 0.857, rmse 0.0805
# Epoch 36/40 | train: loss 0.4164, acc 0.891, rmse 0.0884 | val: loss 0.4920, acc 0.856, rmse 0.0812
# Epoch 37/40 | train: loss 0.4160, acc 0.890, rmse 0.0884 | val: loss 0.4925, acc 0.856, rmse 0.0805
# Epoch 38/40 | train: loss 0.4132, acc 0.892, rmse 0.0884 | val: loss 0.4965, acc 0.856, rmse 0.0809
# Epoch 39/40 | train: loss 0.3899, acc 0.900, rmse 0.0875 | val: loss 0.4697, acc 0.862, rmse 0.0795
# Epoch 40/40 | train: loss 0.3772, acc 0.905, rmse 0.0874 | val: loss 0.4747, acc 0.861, rmse 0.0797

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plot of accuracy, loss and rmse

# %%
import matplotlib.pyplot as plt


def plot_training_history(history: dict[str, list[float]],
                          config: dict) -> None:
    """
    Plot training + validation curves, and display key hyperparameters.
    """
    epochs = range(1, len(history["train_loss"]) + 1)

    # ------ Create plot ------
    plt.figure(figsize=(15, 4))

    # Loss
    plt.subplot(1, 3, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Valid Loss")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Valid Acc")
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # RMSE
    plt.subplot(1, 3, 3)
    plt.plot(epochs, history["train_rmse"], label="Train RMSE")
    plt.plot(epochs, history["val_rmse"], label="Valid RMSE")
    plt.title("RMSE")
    plt.xlabel("Epoch")
    plt.ylabel("RMSE")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # ------ Add small hyperparameter box ------
    text = (
        f"latent_dim = {config['latent_dim']}\n"
        f"lambda_recon = {config['lambda_recon']}\n"
        f"lr = {config['lr']}\n"
    )

    plt.gcf().text(
        0.92, 0.5, text,
        fontsize=10,
        fontfamily="monospace",
        va="center",
        bbox=dict(facecolor="white", edgecolor="gray", alpha=0.7)
    )

    plt.tight_layout(rect=[0, 0, 0.9, 1])  # leave space for the box
    plt.show()
    
# Plot history for each experiments   
for i, exp in enumerate(experiments):
    print(f"\n===== PLOTTING HISTORY FOR EXPERIMENT {i} =====")
    plot_training_history(exp["history"], exp["config"])
# Out:
# ===== PLOTTING HISTORY FOR EXPERIMENT 0 =====
# ===== PLOTTING HISTORY FOR EXPERIMENT 1 =====
# ===== PLOTTING HISTORY FOR EXPERIMENT 2 =====
# ===== PLOTTING HISTORY FOR EXPERIMENT 3 =====
# ===== PLOTTING HISTORY FOR EXPERIMENT 4 =====
# ===== PLOTTING HISTORY FOR EXPERIMENT 5 =====

# %% [markdown]
# ## Image reconstruction

# %%
from torchvision.utils import make_grid

@torch.no_grad()
def show_reconstructions(
    model: torch.nn.Module,
    loader: torch.utils.data.DataLoader,
    n: int = 8,
    device: str | None = None,
    title: str = "Reconstructions with Errors"
) -> None:
    """
    Display original images (top) and their reconstructions (bottom)
    for n samples from the first batch, with per-image reconstruction
    errors (MSE) annotated above each column.
    """
    device = device or next(model.parameters()).device
    model.eval()

    # Get one mini-batch
    X, _ = next(iter(loader))
    X = X.to(device)[:n]

    # Forward pass
    _, X_hat, _ = model(X)

    # Compute per-sample MSE over pixels
    errors = F.mse_loss(X_hat, X, reduction="none")
    errors = errors.view(errors.size(0), -1).mean(dim=1).detach().cpu().numpy()

    # Combine originals and reconstructions into one grid (2 rows)
    both = torch.cat([X, X_hat.clamp(0, 1)], dim=0)
    grid = make_grid(both, nrow=n, padding=2)

    # Plot grid
    plt.figure(figsize=(1.8 * n, 3.6))
    plt.imshow(grid.permute(1, 2, 0).detach().cpu())
    plt.axis("off")
    plt.title(title)

    # Annotate with reconstruction error (MSE) above each column
    for i, err in enumerate(errors):
        plt.text(
            x=i * (grid.shape[2] / n) + 8,
            y=20,
            s=f"MSE={err:.4f}",
            color="white",
            fontsize=9,
            weight="bold",
            bbox=dict(facecolor="black", alpha=0.6, boxstyle="round,pad=0.2")
        )

    plt.show()

# Plot the reconstruction for each experiment
for i, exp in enumerate(experiments):
    cfg = exp["config"]

    print(f"\n===== RECONSTRUCTIONS FOR EXPERIMENT {i} =====")
    print(f" latent_dim     = {cfg['latent_dim']}")
    print(f" lambda_recon   = {cfg['lambda_recon']}")
    print(f" lr             = {cfg['lr']}")
    show_reconstructions(exp["model"], test_loader, n=10, title="Test set reconstructions with MSE")
# Out:
# ===== RECONSTRUCTIONS FOR EXPERIMENT 0 =====
#  latent_dim     = 64
#  lambda_recon   = 50
#  lr             = 0.0003
# ===== RECONSTRUCTIONS FOR EXPERIMENT 1 =====
#  latent_dim     = 32
#  lambda_recon   = 50
#  lr             = 0.0001
# ===== RECONSTRUCTIONS FOR EXPERIMENT 2 =====
#  latent_dim     = 64
#  lambda_recon   = 0
#  lr             = 0.0001
# ===== RECONSTRUCTIONS FOR EXPERIMENT 3 =====
#  latent_dim     = 32
#  lambda_recon   = 1
#  lr             = 0.001
# ===== RECONSTRUCTIONS FOR EXPERIMENT 4 =====
#  latent_dim     = 128
#  lambda_recon   = 1
#  lr             = 0.0001
# ===== RECONSTRUCTIONS FOR EXPERIMENT 5 =====
#  latent_dim     = 128
#  lambda_recon   = 10
#  lr             = 0.001

# %% [markdown]
# ## Model selection

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

def plot_experiment_bars(experiments):
    """
    Bar plot of final val_acc and val_rmse for each experiment.
    Legend outside, values on bars, and hyperparameters under each experiment.
    """
    exp_ids = list(range(len(experiments)))
    val_accs = []
    val_rmses = []
    labels = []

    for i, exp in enumerate(experiments):
        hist = exp["history"]
        cfg = exp["config"]

        val_accs.append(hist["val_acc"][-1])
        val_rmses.append(hist["val_rmse"][-1])

        labels.append(
            f"Exp {i}\n"
            f"ld={cfg['latent_dim']}, lam={cfg['lambda_recon']}\n"
            f"lr={cfg['lr']}"
        )

    x = np.arange(len(exp_ids))
    width = 0.35

    plt.figure(figsize=(12, 6))

    bars_acc = plt.bar(x - width/2, val_accs, width, label="Val Accuracy")
    bars_rmse = plt.bar(x + width/2, val_rmses, width, label="Val RMSE")

    for bar in bars_acc:
        h = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, h + 0.002,
                 f"{h:.3f}", ha="center", va="bottom", fontsize=9)

    for bar in bars_rmse:
        h = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, h + 0.002,
                 f"{h:.3f}", ha="center", va="bottom", fontsize=9)

    plt.xticks(x, labels)
    plt.ylabel("Metric value")
    plt.title("Final Validation Accuracy and RMSE per Experiment")

    # FIXED: use bbox_to_anchor, not bbox_anchor
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.grid(True, axis="y", alpha=0.3)
    plt.tight_layout()
    plt.show()


plot_experiment_bars(experiments)

# %%
exp0 = experiments[0]

model0   = exp0["model"]
history0 = exp0["history"]
config0  = exp0["config"]

# %% [markdown]
# ## Classification report

# %%
from sklearn.metrics import classification_report

@torch.no_grad()
def evaluate_classification_report(
    model: torch.nn.Module,
    loader: torch.utils.data.DataLoader,
    class_names: list[str],
    device: str | None = None,
    digits: int = 3
) -> tuple[str, np.ndarray, np.ndarray]:
    """
    Evaluate the model and print a sklearn-style classification report.
    """
    device = device or next(model.parameters()).device
    model.eval()

    y_true, y_pred = [], []

    for X, y in loader:
        X, y = X.to(device), y.to(device)
        _, _, logits = model(X)
        preds = logits.argmax(dim=1)
        y_true.append(y.cpu())
        y_pred.append(preds.cpu())

    y_true = torch.cat(y_true).numpy()
    y_pred = torch.cat(y_pred).numpy()

    # Generate and print the report using known class names
    report = classification_report(
        y_true,
        y_pred,
        target_names=class_names,
        digits=digits,
        zero_division=0
    )

    print("\n[Classification Report]")
    print(report)

    return report, y_true, y_pred


report, y_true, y_pred = evaluate_classification_report(
    model= model0, # select the optimal model
    loader=test_loader,
    class_names=cifar10_classes,
    device=device
)
# Out:
# [Classification Report]
#               precision    recall  f1-score   support
#
#     airplane      0.852     0.876     0.864      1000
#   automobile      0.921     0.928     0.924      1000
#         bird      0.828     0.742     0.783      1000
#          cat      0.707     0.680     0.693      1000
#         deer      0.803     0.840     0.821      1000
#          dog      0.720     0.796     0.756      1000
#         frog      0.870     0.891     0.880      1000
#        horse      0.909     0.856     0.882      1000
#         ship      0.919     0.920     0.920      1000
#        truck      0.914     0.903     0.908      1000
#
#     accuracy                          0.843     10000
#    macro avg      0.844     0.843     0.843     10000
# weighted avg      0.844     0.843     0.843     10000

# %% [markdown]
# ## Confusion matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(
    y_true: np.ndarray,
    y_pred: np.ndarray,
    class_names: list[str],
    normalize: bool = False
) -> None:
    """
    Plot a clean confusion matrix heatmap.
    """
    cm = confusion_matrix(y_true, y_pred, normalize="true" if normalize else None)

    plt.figure(figsize=(7, 6))
    sns.heatmap(
        cm,
        annot=True,
        fmt=".2f" if normalize else "d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.title("Confusion Matrix" + (" (Normalized)" if normalize else ""))
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.show()

# After getting y_true and y_pred from evaluation
plot_confusion_matrix(y_true, y_pred, class_names=cifar10_classes, normalize=False)

# %% [markdown]
# # 2D latent visualization
# ## TSNE

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def to_numpy(x: object) -> np.ndarray:
    """
    Turn a tensor or array into a numpy array.
    """
    if isinstance(x, torch.Tensor):
        return x.detach().cpu().numpy()
    return np.asarray(x)

@torch.no_grad()
def extract_latents(model: torch.nn.Module,
                    loader,
                    device: str | None = None) -> tuple[torch.Tensor, torch.Tensor]:
    """
    Pass all images through the model and collect:
    - Z: latent vectors
    - y: labels
    """
    if device is None:
        device = next(model.parameters()).device

    model.eval()
    Z_list = []
    y_list = []

    for X, y in loader:
        X = X.to(device)

        # model should return (z, recon, logits)
        z, _, _ = model(X)

        Z_list.append(z.cpu())
        y_list.append(y.cpu())

    Z = torch.cat(Z_list, dim=0)
    y = torch.cat(y_list, dim=0)
    return Z, y

def compute_tsne_2d(Z) -> np.ndarray:
    """
    Make a 2D version of the latent vectors using t-SNE.
    """
    Z_np = to_numpy(Z)
    tsne = TSNE(
        n_components=2,
        init="pca",
        learning_rate="auto",
    )
    return tsne.fit_transform(Z_np)

def plot_latent_2d(emb_2d,
                   y,
                   class_names: list[str],
                   title: str = "Latent space") -> None:
    """
    Make a scatter plot of 2D points.
    Each point is colored by its class.
    """
    y_np = to_numpy(y)

    plt.figure(figsize=(7, 6))
    for cls in np.unique(y_np):
        mask = (y_np == cls)
        plt.scatter(
            emb_2d[mask, 0],
            emb_2d[mask, 1],
            s=12,
            alpha=0.8,
            label=class_names[int(cls)],
        )

    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title(title)
    plt.legend(markerscale=1.5, fontsize=8)
    plt.tight_layout()
    plt.show()

# %%
# Extract latents and labels from the model on the test set
Z, y = extract_latents(model0, test_loader)

# t-SNE analysis
# Compute t-SNE 2D embedding
emb_tsne_2d: np.ndarray = compute_tsne_2d(Z)

# Plot t-SNE latent space
plot_latent_2d(
    emb_2d=emb_tsne_2d,
    y=y,
    class_names=cifar10_classes,
    title="Latent space (t-SNE 2D)"
)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA


def compute_pca(Z: np.ndarray,
                n_components: int | None = None) -> PCA | tuple[np.ndarray, PCA]:
    """
    Run PCA on the latent vectors.

    n_components:
      None  -> keep all PCA components
      number -> reduce to that many components (e.g., 2)

    Returns:
      - If n_components is None:
            PCA model
      - Otherwise:
            (reduced_array, PCA model)
    """
    Z_np = np.asarray(Z)

    if n_components is None:
        # Full PCA, no reduction
        pca = PCA()
        pca.fit(Z_np)
        return pca

    # PCA with reduction
    pca = PCA(n_components=n_components)
    emb: np.ndarray = pca.fit_transform(Z_np)
    return emb, pca


def plot_pca_explained_variance(pca: PCA) -> None:
    """
    Plot how much each PCA component explains,
    and how the variance builds up.
    """
    var_ratio: np.ndarray = pca.explained_variance_ratio_
    cum_var: np.ndarray = np.cumsum(var_ratio)
    components: np.ndarray = np.arange(1, len(var_ratio) + 1)

    plt.figure(figsize=(8, 4))

    plt.bar(components, var_ratio, alpha=0.7, label="Component variance")
    plt.plot(components, cum_var, marker="o", label="Cumulative")

    plt.xlabel("PCA Component")
    plt.ylabel("Variance Ratio")
    plt.title("PCA Variance")
    plt.ylim(0, 1.05)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# PCA analysis
# PCA reduced to 2D → emb_pca_2d is an array, pca_2d is a PCA model
emb_pca_2d: np.ndarray
pca_2d: PCA
emb_pca_2d, pca_2d = compute_pca(Z, n_components=2)

plot_latent_2d(
    emb_2d=emb_pca_2d,
    y=y,
    class_names=cifar10_classes,
    title="Latent space (PCA 2D)"
)

# Full PCA (all components) → only the PCA model is returned
pca_full: PCA = compute_pca(Z, n_components=None)

plot_pca_explained_variance(pca_full)

# %% [markdown]
# ## Umap

# %%
import umap  # pip install umap-learn

def compute_umap_2d(Z: np.ndarray,
                    n_neighbors: int = 50,
                    min_dist: float = 0.05,
                    metric: str = "cosine") -> np.ndarray:
    """
    Make a 2D UMAP embedding from latent vectors.
    """
    Z_np = to_numpy(Z)  # uses your existing helper
    reducer = umap.UMAP(
        n_components=2,
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        metric=metric,
        random_state=42,
    )
    emb_2d: np.ndarray = reducer.fit_transform(Z_np)
    return emb_2d

# UMAP 2D embedding
emb_umap_2d: np.ndarray = compute_umap_2d(Z)

# Plot UMAP latent space (reuses your plot_latent_2d)
plot_latent_2d(
    emb_2d=emb_umap_2d,
    y=y,
    class_names=cifar10_classes,
    title="Latent space (UMAP 2D)"
)
# Out:
# /storage/homefs/ae04q066/.conda/envs/py3.10/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# # Results interpretation
